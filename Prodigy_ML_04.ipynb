# %%
! pip install -q keras

# %%
import numpy as np
import math
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import glob
from tqdm import tqdm
import pickle
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt
from scipy.spatial.distance import cdist
import keras
from keras.optimizers import *
from keras.models import Model
from keras.layers import *

from keras import backend as K
import keras
import tensorflow as tf

import google.colab.files

# %%
random.seed(1234)

class Config():
    def __init__(self):
        self.frame_l = 32 # the length of frames
        self.joint_n = 15 # the number of joints
        self.joint_d = 2 # the dimension of joints
        self.clc_num = 21 # the number of class
        self.feat_d = 105
        self.filters = 64
C = Config()

# %%
# Temple resizing function
def zoom(p,target_l=64,joints_num=25,joints_dim=3):
    l = p.shape[0]
    p_new = np.empty([target_l,joints_num,joints_dim])
    for m in range(joints_num):
        for n in range(joints_dim):
            p[:,m,n] = medfilt(p[:,m,n],3)
            p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
    return p_new



# Calculate JCD feature
def norm_scale(x):
    return (x-np.mean(x))/np.mean(x)

def get_CG(p,C):
    M = []
    iu = np.triu_indices(C.joint_n,1,C.joint_n)
    for f in range(C.frame_l):
        d_m = cdist(p[f],p[f],'euclidean')
        d_m = d_m[iu]
        M.append(d_m)
    M = np.stack(M)
    M = norm_scale(M)
    return M


# Genrate dataset
def data_generator(T,C,le):
    X_0 = []
    X_1 = []
    Y = []
    for i in tqdm(range(len(T['pose']))):
        p = np.copy(T['pose'][i])
        p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)

        label = np.zeros(C.clc_num)
        label[le.transform(T['label'])[i]-1] = 1

        M = get_CG(p,C)

        X_0.append(M)
        X_1.append(p)
        Y.append(label)

    X_0 = np.stack(X_0)
    X_1 = np.stack(X_1)
    Y = np.stack(Y)
    return X_0,X_1,Y

# %%
def poses_diff(x):
    H, W = x.get_shape()[1],x.get_shape()[2]
    x = tf.subtract(x[:,1:,...],x[:,:-1,...])
    x = tf.image.resize(x,size=[H,W])
    return x

def pose_motion(P,frame_l):
    P_diff_slow = Lambda(lambda x: poses_diff(x))(P)
    P_diff_slow = Reshape((frame_l,-1))(P_diff_slow)
    P_fast = Lambda(lambda x: x[:,::2,...])(P)
    P_diff_fast = Lambda(lambda x: poses_diff(x))(P_fast)
    P_diff_fast = Reshape((int(frame_l/2),-1))(P_diff_fast)
    return P_diff_slow,P_diff_fast

def c1D(x,filters,kernel):
    x = Conv1D(filters, kernel_size=kernel,padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def block(x,filters):
    x = c1D(x,filters,3)
    x = c1D(x,filters,3)
    return x

def d1D(x,filters):
    x = Dense(filters,use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def build_FM(frame_l=32,joint_n=22,joint_d=2,feat_d=231,filters=16):
    M = Input(shape=(frame_l,feat_d))
    P = Input(shape=(frame_l,joint_n,joint_d))

    diff_slow,diff_fast = pose_motion(P,frame_l)

    x = c1D(M,filters*2,1)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,3)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,1)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x_d_slow = c1D(diff_slow,filters*2,1)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,3)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,1)
    x_d_slow = MaxPool1D(2)(x_d_slow)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)

    x_d_fast = c1D(diff_fast,filters*2,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,3)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)

    x = concatenate([x,x_d_slow,x_d_fast])
    x = block(x,filters*2)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*4)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*8)
    x = SpatialDropout1D(0.1)(x)

    return Model(inputs=[M,P],outputs=x)


def build_DD_Net(C):
    M = Input(name='M', shape=(C.frame_l,C.feat_d))
    P = Input(name='P', shape=(C.frame_l,C.joint_n,C.joint_d))

    FM = build_FM(C.frame_l,C.joint_n,C.joint_d,C.feat_d,C.filters)

    x = FM([M,P])

    x = GlobalMaxPool1D()(x)

    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = Dense(C.clc_num, activation='softmax')(x)

    ######################Self-supervised part
    model = Model(inputs=[M,P],outputs=x)
    return model

# %%
DD_Net = build_DD_Net(C)
DD_Net.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  M (InputLayer)              [(None, 32, 105)]            0         []
#
#  P (InputLayer)              [(None, 32, 15, 2)]          0         []
#
#  model (Functional)          (None, 4, 512)               1714816   ['M[0][0]',
#                                                                      'P[0][0]']
#
#  global_max_pooling1d (Glob  (None, 512)                  0         ['model[0][0]']
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 128)                  65536     ['global_max_pooling1d[0][0]']
#
#  batch_normalization_15 (Ba  (None, 128)                  512       ['dense[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 128)                  0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  dropout (Dropout)           (None, 128)                  0         ['leaky_re_lu_15[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16384     ['dropout[0][0]']
#
#  batch_normalization_16 (Ba  (None, 128)                  512       ['dense_1[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 128)                  0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['leaky_re_lu_16[0][0]']
#
#  dense_2 (Dense)             (None, 21)                   2709      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 1800469 (6.87 MB)
# Trainable params: 1794837 (6.85 MB)
# Non-trainable params: 5632 (22.00 KB)
# __________________________________________________________________________________________________

# %%
# !wget https://github.com/fandulu/DD-Net/archive/master.zip
# !unzip master.zip
# !rm master.zip
# Out:
# --2023-12-12 15:24:35--  https://github.com/fandulu/DD-Net/archive/master.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master [following]
# --2023-12-12 15:24:35--  https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [        <=>         ]  79.09M  14.1MB/s    in 5.6s
#
# 2023-12-12 15:24:41 (14.1 MB/s) - ‘master.zip’ saved [82934337]
#
# Archive:  master.zip
# f26a9994b0bafc41096fa269eab89c2757d71499
#    creating: DD-Net-master/
#   inflating: DD-Net-master/.gitignore
#    creating: DD-Net-master/JHMDB/
#   inflating: DD-Net-master/JHMDB/README.md
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_heavy.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_lite.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_middle.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_data_preprocessing.ipynb
#   inflating: DD-Net-master/JHMDB/utils.py
#    creating: DD-Net-master/JHMDB/weights/
#  extracting: DD-Net-master/JHMDB/weights/__init__.py
#   inflating: DD-Net-master/LICENSE
#   inflating: DD-Net-master/README.md
#    creating: DD-Net-master/SHREC/
#   inflating: DD-Net-master/SHREC/README.md
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_lite.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_data_preprocessing.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_lite.ipynb
#    creating: DD-Net-master/SHREC/images/
#   inflating: DD-Net-master/SHREC/images/SHREC_14.png
#   inflating: DD-Net-master/SHREC/images/SHREC_28.png
#   inflating: DD-Net-master/SHREC/utils.py
#    creating: DD-Net-master/SHREC/weights/
#  extracting: DD-Net-master/SHREC/weights/.gitkeep
#  extracting: DD-Net-master/SHREC/weights/__init__.py
#    creating: DD-Net-master/data/
#    creating: DD-Net-master/data/JHMDB/
#   inflating: DD-Net-master/data/JHMDB/GT_test_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_3.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_3.pkl
#   inflating: DD-Net-master/data/JHMDB/joint_positions.zip
#   inflating: DD-Net-master/data/JHMDB/splits.zip
#    creating: DD-Net-master/data/SHREC/
#  extracting: DD-Net-master/data/SHREC/__init__.py
#   inflating: DD-Net-master/data/SHREC/test.pickle
#   inflating: DD-Net-master/data/SHREC/test.pkl
#   inflating: DD-Net-master/data/SHREC/train.pickle
#   inflating: DD-Net-master/data/SHREC/train.pkl
#    creating: DD-Net-master/mics/
#  extracting: DD-Net-master/mics/__init__.py
#   inflating: DD-Net-master/mics/demo.png
#   inflating: DD-Net-master/mics/look.gif
#   inflating: DD-Net-master/mics/paper.png

# %%
Train = pickle.load(open("/content/DD-Net-master/data/JHMDB/GT_train_1.pkl", "rb"))
Test = pickle.load(open("/content/DD-Net-master/data/JHMDB/GT_test_1.pkl", "rb"))

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(Train['label'])

X_0,X_1,Y = data_generator(Train,C,le)
X_test_0,X_test_1,Y_test = data_generator(Test,C,le)
# Out:
#   0%|          | 0/433 [00:00<?, ?it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#   3%|▎         | 14/433 [00:00<00:03, 139.03it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#   6%|▋         | 28/433 [00:00<00:04, 95.07it/s] <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#   9%|▉         | 39/433 [00:00<00:04, 85.20it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  11%|█         | 48/433 [00:00<00:04, 79.95it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  13%|█▎        | 57/433 [00:00<00:04, 81.75it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  15%|█▌        | 66/433 [00:00<00:04, 79.75it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  17%|█▋        | 75/433 [00:00<00:04, 77.02it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  19%|█▉        | 83/433 [00:01<00:05, 68.71it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  21%|██        | 91/433 [00:01<00:06, 56.01it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  23%|██▎       | 98/433 [00:01<00:06, 52.48it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  24%|██▍       | 104/433 [00:01<00:06, 48.17it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  26%|██▌       | 113/433 [00:01<00:05, 55.44it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  27%|██▋       | 119/433 [00:01<00:05, 54.59it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  29%|██▉       | 126/433 [00:01<00:05, 57.78it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  31%|███       | 133/433 [00:02<00:04, 60.90it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  33%|███▎      | 141/433 [00:02<00:04, 64.46it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  34%|███▍      | 148/433 [00:02<00:04, 62.09it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  36%|███▌      | 155/433 [00:02<00:05, 54.92it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  37%|███▋      | 161/433 [00:02<00:05, 48.64it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  39%|███▉      | 168/433 [00:02<00:05, 51.32it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  40%|████      | 174/433 [00:02<00:05, 48.13it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  41%|████▏     | 179/433 [00:02<00:05, 45.08it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  42%|████▏     | 184/433 [00:03<00:06, 38.19it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  44%|████▎     | 189/433 [00:03<00:06, 37.61it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  45%|████▍     | 193/433 [00:03<00:06, 37.98it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  45%|████▌     | 197/433 [00:03<00:06, 36.32it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  46%|████▋     | 201/433 [00:03<00:06, 33.24it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# ...
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  62%|██████▎   | 110/176 [00:01<00:01, 63.48it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  66%|██████▋   | 117/176 [00:01<00:00, 62.49it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  70%|███████   | 124/176 [00:01<00:00, 64.07it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  74%|███████▍  | 131/176 [00:01<00:00, 65.55it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  78%|███████▊  | 138/176 [00:01<00:00, 62.90it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  82%|████████▏ | 145/176 [00:02<00:00, 62.24it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  88%|████████▊ | 154/176 [00:02<00:00, 68.22it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  91%|█████████▏| 161/176 [00:02<00:00, 67.99it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  95%|█████████▌| 168/176 [00:02<00:00, 67.24it/s]<ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-6-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# 100%|██████████| 176/176 [00:02<00:00, 69.72it/s]

# %%
lr = 1e-3
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
                    batch_size=len(Y),
                    epochs=600,
                    verbose=True,
                    shuffle=True,
                    callbacks=[lrScheduler],
                    validation_data=([X_test_0,X_test_1],Y_test)
                    )
lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
                    batch_size=len(Y),
                    epochs=600,
                    verbose=True,
                    shuffle=True,
                    callbacks=[lrScheduler],
                    validation_data=([X_test_0,X_test_1],Y_test)
                    )
# Out:
# Epoch 1/600
# 1/1 [==============================] - 17s 17s/step - loss: 3.8515 - accuracy: 0.0393 - val_loss: 3.0396 - val_accuracy: 0.0682 - lr: 0.0010
# Epoch 2/600
# 1/1 [==============================] - 3s 3s/step - loss: 3.2598 - accuracy: 0.1501 - val_loss: 3.0351 - val_accuracy: 0.0739 - lr: 0.0010
# Epoch 3/600
# 1/1 [==============================] - 3s 3s/step - loss: 2.9098 - accuracy: 0.1732 - val_loss: 3.0306 - val_accuracy: 0.1250 - lr: 0.0010
# Epoch 4/600
# 1/1 [==============================] - 3s 3s/step - loss: 2.7503 - accuracy: 0.2148 - val_loss: 3.0230 - val_accuracy: 0.1818 - lr: 0.0010
# Epoch 5/600
# 1/1 [==============================] - 2s 2s/step - loss: 2.5776 - accuracy: 0.2794 - val_loss: 3.0101 - val_accuracy: 0.1705 - lr: 0.0010
# Epoch 6/600
# 1/1 [==============================] - 2s 2s/step - loss: 2.3978 - accuracy: 0.2933 - val_loss: 2.9939 - val_accuracy: 0.1875 - lr: 0.0010
# Epoch 7/600
# 1/1 [==============================] - 2s 2s/step - loss: 2.2168 - accuracy: 0.3418 - val_loss: 2.9747 - val_accuracy: 0.1932 - lr: 0.0010
# Epoch 8/600
# 1/1 [==============================] - 2s 2s/step - loss: 2.0782 - accuracy: 0.3718 - val_loss: 2.9542 - val_accuracy: 0.1761 - lr: 0.0010
# Epoch 9/600
# 1/1 [==============================] - 3s 3s/step - loss: 1.9934 - accuracy: 0.4111 - val_loss: 2.9328 - val_accuracy: 0.1705 - lr: 0.0010
# Epoch 10/600

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
